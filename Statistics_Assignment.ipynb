# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

# %%
df = pd.read_csv(r'C:\Users\HP\Downloads\Students_Performance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3      female
# 4      female
#         ...
# 995      male
# 996      male
# 997      male
# 998      male
# 999      male
# Name: gender, Length: 1000, dtype: object

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df['gender']
df[['math score', 'reading score', 'writing score']].mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
grouped = df.groupby('test preparation course')

# %%
average_scores = grouped[['math score', 'reading score', 'writing score']].mean()

# %%
print(average_scores)
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
from scipy.stats import f_oneway

# %%
df['gender']
f_stat1,p_value1 = f_oneway(df['math score'],df['reading score'],df['writing score'])

# %%
p_value1
# Out:
# 1.0869394795813066e-05

# %%
if p_value1<0.05:
    print('Reject Null Hypothesis')
else:
    print('Accept Null Hypothesis')
# Out:
# Reject Null Hypothesis

# %%
grouped = df.groupby('test preparation course')

# %%
f_stat2,p_value2 = f_oneway(df['math score'],df['reading score'],df['writing score'])

# %%
p_value2
# Out:
# 1.0869394795813066e-05

# %%
if p_value2<0.05:
    print('Reject Null Hypothesis')
else:
    print('Accept Null Hypothesis')
# Out:
# Reject Null Hypothesis

# %%
df.head(25)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group B                 high school  free/reduced
# 2   female        group B            some high school  free/reduced
# 3   female        group B                some college      standard
# 4   female        group C                some college  free/reduced
# 5   female        group B                 high school  free/reduced
# 6   female        group B            some high school  free/reduced
# 7   female        group D          associate's degree  free/reduced
# 8   female        group D            some high school  free/reduced
# 9   female        group C                 high school      standard
# 10  female        group C            some high school  free/reduced
# 11  female        group D           bachelor's degree  free/reduced
# 12  female        group B            some high school      standard
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df['math score'] = df['math score'].apply(lambda x:1 if x<25 else 0)

# %%
df.head(25)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group B                 high school  free/reduced
# 2   female        group B            some high school  free/reduced
# 3   female        group B                some college      standard
# 4   female        group C                some college  free/reduced
# 5   female        group B                 high school  free/reduced
# 6   female        group B            some high school  free/reduced
# 7   female        group D          associate's degree  free/reduced
# 8   female        group D            some high school  free/reduced
# 9   female        group C                 high school      standard
# 10  female        group C            some high school  free/reduced
# 11  female        group D           bachelor's degree  free/reduced
# 12  female        group B            some high school      standard
# ...

# %%
df1 = pd.read_csv(r'C:\Users\HP\Downloads\Sales_add.csv')

# %%
df1
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
from scipy.stats import ttest_ind

# %%
df1['Sales_before_digital_add(in $)'].mean()
# Out:
# 149239.95454545456

# %%
df1['Sales_After_digital_add(in $)'].mean()
# Out:
# 231123.72727272726

# %%
z_test1,p_value1 = ttest_ind(df1['Sales_before_digital_add(in $)'],df1['Sales_After_digital_add(in $)'])

# %%
p_value1
# Out:
# 2.614368006904645e-16

# %%
if p_value1<0.05:
    print('Reject Null Hypothesis')
else:
    print('Accept Null Hypothesis')
# Out:
# Reject Null Hypothesis

# %%
from scipy.stats import chisquare

# %%
from scipy.stats import chi2_contingency

# %%
df1 = pd.crosstab(df1['Region'],df1['Manager'])
df1
# Out:
# Manager     Manager - A  Manager - B  Manager - C
# Region
# Region - A            4            3            3
# Region - B            4            1            2
# Region - C            1            3            1

# %%
chi2_stst,p_value,dof,exp = chi2_contingency(df1)

# %%
p_value
# Out:
# 0.5493991051158094

# %%
if p_value<0.05:
    print('Reject Null Hypothesis')
else:
    print('Accept Null Hypothesis')
# Out:
# Accept Null Hypothesis
